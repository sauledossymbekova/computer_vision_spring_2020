# %% [markdown]
# # Homework 1
# _Deadline: 01.02.2020.00:00:00_
# ___
#
# In this homework, you need to load your image and use the image for every problem.
#
# You can use Numpy, Matplotlib and __imread__ and __cvtColor__ from OpenCV.
#
# __You cannot use other libraries and functions!__

# %% [markdown]
# ## Problem 1
# ___
# Load and show the image and print shape of the image.

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image=cv2.imread('leaf.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print('Shape of image:', np.shape(image))
plt.imshow(image)
# Out:
# Shape of image: (256, 256, 3)

# %% [markdown]
# ## Problem 2
# ___
# a) You need rotate your the image and do not use functions (You can use functions from Numpy).
#
# b) Show a piece size 50X50 from the lower right corner of the image.
#
# C) Change all elements in the image to 255, in addition, show the result. You can use only arithmetical operations and function __imshow__ from Matplotlib (You can use nothing else from the function or libraries).

# %%
image = cv2.imread("leaf.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print('Shape of image:', np.shape(image))
image_1 = np.rot90(image)
plt.imshow(image_1)
# Out:
# Shape of image: (256, 256, 3)

# %%
image_2=image[205:255,205:255,0]
print('new cropped image:', np.shape(image_2))
plt.imshow(image_2)
# Out:
# new cropped image: (50, 50)

# %%
image[:,:]=(255,255,255)
plt.imshow(image)

# %% [markdown]
# ## Problem 3
# ___
# a) Make your image grayscale use Lightness formula.
#
# b) Make your image sepia used Sepia formula.

# %%
image=cv2.imread('leaf.png')
image_3 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
R = image_3[:,:,0]
G = image_3[:,:,1]
B = image_3[:,:,2]
I=(np.maximum(R,G,B)+np.minimum(R,G,B))
plt.imshow(I)

# %%
image=cv2.imread('leaf.png')
image_4 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
R = image_4[:,:,0]
G = image_4[:,:,1]
B = image_4[:,:,2]
R_out = (R * 0.393) + (G * 0.769) + (B * 0.189)
G_out = (R * 0.349) + (G * 0.686) + (B * 0.168)
B_out = (R * 0.272) + (G * 0.534) + (B * 0.131)
"""for x in R_out:
    if(x > 255): 
        x = 255
for x in G_out:
    if(x > 255): 
        x = 255
for x in B_out:
    if(x > 255): 
        x = 255"""
# I tried to fix a bug, not successfull
image_4[:,:,0] = R_out
image_4[:,:,1] = G_out 
image_4[:,:,2] = B_out
plt.imshow(image_4)
