# %% [markdown]
# # Quiz
# _Start: 22.02.2020.08:00:00_
#
# _Deadline: 22.02.2020.09:00:00_
# ___
#
# During the quiz you can not use any gadgets other than a laptop.
# You must download the picture from the list after downloading the picture disable wifi.
#
# You can use _Numpy, Matplotlib and OpenCV_ but you have to consider problem restrictions(for example, if the task contains a condition not to use the library OpenCV you can not use anything in this library).
#
# __For cheating, you get 0 and are removed from the audience!__
# __For plagiarism you get 0 too!__

# %% [markdown]
# ___
# You must download on _Google Drive_ to download the folder as written in the Excel file "ID_8.xlsx"
# ___

# %% [markdown]
# ## Problem 1 (Practice 1)
# ___
# a) Read the image and show shape
#
# b) Reflect and rotate 90 degrees the image.(not use any library)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2
image = cv2.imread ('10_1.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print('Shape of the image is:', np.shape(image))
plt.imshow(image)
# Out:
# Shape of the image is: (632, 474, 3)

# %%
image_new = np.rot90(image)
print('Rotated image is:')
plt.imshow(image_new)

image_b = cv2.imread ('10_1.png')
image_b = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
v,z,c= np.shape(image)
for x in range(v)
    for y in range(z)
    image_b
# Out:
# Rotated image is:

# %% [markdown]
# ## Problem 2 (Practice 2)
# ___
# a) Draw a square.
#
# b) Draw a circle.

# %%
image = cv2.imread ('10_1.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
image_1 = cv2.line(image, (100,100),(300,100),(255,0,0), 5)
image_2 = cv2.line(image_1, (100,100),(100,300),(255,0,0), 5)
image_3 = cv2.line(image_2, (100,300),(300,300),(255,0,0), 5)
image_square = cv2.line(image_3, (300,300),(300,100), (255,0,0), 5)

image_square2 =cv2.rectangle(image,(200,300),(300,200),(0,255,255),4)
print('Image with square')
plt.imshow(image_square)
# Out:
# Image with square

# %%
image = cv2.imread('10_1.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_circle = cv2.circle(image, (255,300),100, (255,255,0), 5)
print('Image with circle')
plt.imshow(image_circle)
# Out:
# Image with circle

# %% [markdown]
# ## Problem 3 (Practice 3)
# ___
# a) Get rid of the noise. Use filter (5x5)
#
# b) Get rid of the noise. Use Gaussian filter

# %%
image = cv2.imread('10_2.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print('Image without noise, 5*5')


K = np.ones((5,5),np.float32)/(5*5)
image_blur = cv2.filter2D(image,-1,K)
print('Blured image')
plt.imshow(image_blur)
# Out:
# Image without noise, 5*5
# Blured image

# %%
image = cv2.imread('10_2.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print('Image without noise, Gausian filter')
plt.imshow(image)
